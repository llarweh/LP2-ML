# %%
#!pip install plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
training_file = "C:/Users/hp/Documents/GitHub/Customer-Churn-ML-Prediction/Datasets/training_data.csv"

training_data = pd.read_csv(training_file)

# %%
training_data
# Out:
#       Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female            No     Yes         No       1
# 1              1  5575-GNVDE    Male            No      No         No      34
# 2              2  3668-QPYBK    Male            No      No         No       2
# 3              3  7795-CFOCW    Male            No      No         No      45
# 4              4  9237-HQITU  Female            No      No         No       2
# ...          ...         ...     ...           ...     ...        ...     ...
# 5038        2038  6840-RESVB    Male            No     Yes        Yes      24
# 5039        2039  2234-XADUH  Female            No     Yes        Yes      72
# 5040        2040  4801-JZAZL  Female            No     Yes        Yes      11
# 5041        2041  8361-LTMKD    Male           Yes     Yes         No       4
# 5042        2042  3186-AJIEK    Male            No      No         No      66
#
#      PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0              No            No             DSL  ...               No
# 1             Yes            No             DSL  ...              Yes
# 2             Yes            No             DSL  ...               No
# 3              No            No             DSL  ...              Yes
# 4             Yes            No     Fiber optic  ...               No
# ...           ...           ...             ...  ...              ...
# 5038          Yes           Yes             DSL  ...              Yes
# 5039          Yes           Yes     Fiber optic  ...              Yes
# 5040           No            No             DSL  ...               No
# 5041          Yes           Yes     Fiber optic  ...               No
# 5042          Yes            No     Fiber optic  ...              Yes
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 5038         Yes         Yes             Yes        One year              Yes
# 5039          No         Yes             Yes        One year              Yes
# 5040          No          No              No  Month-to-month              Yes
# 5041          No          No              No  Month-to-month              Yes
# 5042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn
# 0              Electronic check      29.850000    29.850000     No
# 1                  Mailed check      56.950001  1889.500000     No
# 2                  Mailed check      53.849998   108.150002    Yes
# 3     Bank transfer (automatic)      42.299999  1840.750000     No
# 4              Electronic check      70.699997   151.649994    Yes
# ...                         ...            ...          ...    ...
# 5038               Mailed check      84.800000  1990.500000     No
# 5039    Credit card (automatic)     103.200000  7362.900000     No
# 5040           Electronic check      29.600000   346.450000     No
# 5041               Mailed check      74.400000   306.600000    Yes
# 5042  Bank transfer (automatic)     105.650000  6844.500000     No
#
# [5043 rows x 22 columns]

# %%
#training_data.drop('Column1', inplace=True, axis=1)

# %%
training_data
# Out:
#       Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0              0  7590-VHVEG  Female            No     Yes         No       1
# 1              1  5575-GNVDE    Male            No      No         No      34
# 2              2  3668-QPYBK    Male            No      No         No       2
# 3              3  7795-CFOCW    Male            No      No         No      45
# 4              4  9237-HQITU  Female            No      No         No       2
# ...          ...         ...     ...           ...     ...        ...     ...
# 5038        2038  6840-RESVB    Male            No     Yes        Yes      24
# 5039        2039  2234-XADUH  Female            No     Yes        Yes      72
# 5040        2040  4801-JZAZL  Female            No     Yes        Yes      11
# 5041        2041  8361-LTMKD    Male           Yes     Yes         No       4
# 5042        2042  3186-AJIEK    Male            No      No         No      66
#
#      PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 0              No            No             DSL  ...               No
# 1             Yes            No             DSL  ...              Yes
# 2             Yes            No             DSL  ...               No
# 3              No            No             DSL  ...              Yes
# 4             Yes            No     Fiber optic  ...               No
# ...           ...           ...             ...  ...              ...
# 5038          Yes           Yes             DSL  ...              Yes
# 5039          Yes           Yes     Fiber optic  ...              Yes
# 5040           No            No             DSL  ...               No
# 5041          Yes           Yes     Fiber optic  ...               No
# 5042          Yes            No     Fiber optic  ...              Yes
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 5038         Yes         Yes             Yes        One year              Yes
# 5039          No         Yes             Yes        One year              Yes
# 5040          No          No              No  Month-to-month              Yes
# 5041          No          No              No  Month-to-month              Yes
# 5042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn
# 0              Electronic check      29.850000    29.850000     No
# 1                  Mailed check      56.950001  1889.500000     No
# 2                  Mailed check      53.849998   108.150002    Yes
# 3     Bank transfer (automatic)      42.299999  1840.750000     No
# 4              Electronic check      70.699997   151.649994    Yes
# ...                         ...            ...          ...    ...
# 5038               Mailed check      84.800000  1990.500000     No
# 5039    Credit card (automatic)     103.200000  7362.900000     No
# 5040           Electronic check      29.600000   346.450000     No
# 5041               Mailed check      74.400000   306.600000    Yes
# 5042  Bank transfer (automatic)     105.650000  6844.500000     No
#
# [5043 rows x 22 columns]

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Univariate analysis focuses on examining individual variables in isolation. For customer churn data, univariate analysis will involve exploring Churn Distribution, Customer Demographics and Service Usage

# %%
# Churn distribution
# Calculate the churn rate (percentage of customers who churned)
churn_counts = training_data['Churn'].value_counts()
churn_percentages = churn_counts / churn_counts.sum() * 100
print("Churn Distribution:")
print(churn_percentages)
# Out:
# Churn Distribution:
# No     73.507833
# Yes    26.492167
# Name: Churn, dtype: float64

# %% [markdown]
# #### The churn distribution shows that approximately 26.5% of customers have churned, while around 73.5% have not churned. This indicates a class imbalance, with the churned class being the minority.

# %%
# Customer demographics - Gender
# Analyzing the gender distributions
sns.set(style="darkgrid")
plt.figure(figsize=(10, 6))
sns.countplot(x='gender', data=training_data)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### The gender distribution analysis reveals the count of customers by gender. It shows that the gender is balanced with male slightly higher than female.

# %%
# Customer demographics - Senior Citizens
# Analyzing the SeniorCitizens distributions
plt.figure(figsize=(10, 6))
training_data['SeniorCitizen'].value_counts().plot(kind='bar')
plt.title('Senior Citizens Distribution')
plt.xlabel('Senior Citizens')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### The gender distribution analysis reveals the count of customers by senior citizens. It shows that there are whole lot more of non-senior citizens than senior citizens.

# %%
# Service usage - Monthly Charges
# Examining the Average monthly charges with a box plots
plt.figure(figsize=(10, 6))
sns.boxplot(x='MonthlyCharges', data=training_data)
plt.title('Monthly Charges')
plt.xlabel('Charges')
plt.show()

# %% [markdown]
# #### The box plot for monthly charges gives an overview of the distribution of charges among customers. It shows the range, median, quartiles, and any potential outliers in the monthly charges. With this, we can see that the average is around 70 with 20 being the lowest and 120 the highest charge per month.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# #### Bivariate analysis explores the relationship between two variables. In the case of customer churn data, bivariate analysis can help uncover potential correlations or dependencies between different variables and churn

# %%
# Churn by gender
# Analyzing the Churn Rate by Gender to observe any patterns associated with churn
gender_churn = training_data.groupby('PaymentMethod')['Churn'].value_counts(normalize=True).unstack().reset_index()
gender_churn.rename(columns={'No': 'No Churn', 'Yes': 'Churn'}, inplace=True)

fig = px.bar(gender_churn, x='PaymentMethod', y=['No Churn', 'Churn'], barmode='stack', title='Churn by Gender')
fig.show()
# Out:
# <div>                            <div id="f76b50c8-5d3c-461f-97f6-faf4944f16fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f76b50c8-5d3c-461f-97f6-faf4944f16fe")) {                    Plotly.newPlot(                        "f76b50c8-5d3c-461f-97f6-faf4944f16fe",                        [{"alignmentgroup":"True","hovertemplate":"variable=No Churn<br>PaymentMethod=%{x}<br>value=%{y}<extra></extra>","legendgroup":"No Churn","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No Churn","offsetgroup":"No Churn","orientation":"v","showlegend":true,"textposition":"auto","x":["Bank transfer (automatic)","Credit card (automatic)","Electronic check","Mailed check"],"xaxis":"x","y":[0.824,0.8458715596330275,0.5541176470588235,0.8120567375886525],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Churn<br>PaymentMethod=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Churn","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Churn","offsetgroup":"Churn","orientation":"v","showlegend":true,"textposition":"auto","x":["Bank transfer (automatic)","Credit card (automatic)","Electronic check","Mailed check"],"xaxis":"x","y":[0.176,0.15412844036697249,0.44588235294117645,0.1879432624113475],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth" ...

# %% [markdown]
# #### The stacked bar chart demonstrates the churn rates categorized by gender. It shows that there is about 80% No Churn rate in both Male and Female and about 20% Churn rate in both too, so there's no pattern in genders.

# %%
# Churn and service usage - Monthly Charges
# Analyzing the Churn Rate by Monthly Charges to observe any patterns associated with churn
fig = px.scatter(training_data, x='MonthlyCharges', y='Churn', color='Churn', title='Churn and Monthly Charges')
fig.show()
# Out:
# <div>                            <div id="736f1dc5-d78f-4075-b1f7-a66391c6f377" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("736f1dc5-d78f-4075-b1f7-a66391c6f377")) {                    Plotly.newPlot(                        "736f1dc5-d78f-4075-b1f7-a66391c6f377",                        [{"hovertemplate":"Churn=%{y}<br>MonthlyCharges=%{x}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"No","showlegend":true,"x":[29.85000038,56.95000076,42.29999924,89.09999847,29.75,56.15000153,49.95000076,18.95000076,100.3499985,105.5,113.25,20.64999962,106.6999969,90.05000305,19.79999924,59.90000153,59.59999847,55.29999924,90.25,96.34999847,95.5,66.15000153,20.20000076,45.25,99.90000153,74.80000305,49.54999924,69.19999695,20.75,79.84999847,76.19999695,84.5,49.25,79.75,64.15000153,90.25,69.5,74.84999847,99.65000153,108.4499969,24.95000076,107.5,100.5,89.90000153,42.09999847,54.40000153,75.30000305,78.90000153,79.19999695,20.14999962,79.84999847,49.04999924,20.39999962,111.5999985,24.25,64.5,110.5,55.65000153,54.65000153,74.75,25.89999962,50.54999924,103.8000031,20.14999962,99.30000305,62.15000153,20.64999962,19.95000076,33.75,82.05000305,74.69999695,84.0,111.0500031,100.9000015,66.84999847,21.0,20.20000076,19.45000076,95.0,45.54999924,24.29999924,104.1500015,30.14999962,94.34999847,19.39999962,57.95000076,91.65000153,54.59999847,89.84999847,31.04999924,20.64999962,85.19999695,99.80000305,20.70000076,50.70000076,20.85000038,88.94999695,23.54999924,19.75,56.45000076,85.94999695,50.54999924,25.70000076,75.0,20.20000076,19.60000038,88.05000305,101.0500031,84.30000305,23.95000076,99.05000305,19.60000038,64.5,69.5,68.55000305,108.1500015,86.09999847,19.70000076,80.90000153,84.15000153,20.14999962,64.25,25.70000076,56.0,69.69999695,73.90000153,20.60000038,19.89999962,89.05000305,20.39999962,84.25,81.94999695,20.54999924,24.70000076,105.3499985,20.54999924,45.29999924,74.75,51.79999924,30.39999962,19.64999962,56.59999847,71.90000153,19.75,109.6999969,19.29999924,96.55000305,24.10000038,111.3499985,112.25,20.75,101.9000015,80.05000305,105.5500031,78.30000305,68.84999847,79.94999695,55.45000076,102.4499969,25.25,19.75,20.0,86.80000305,58.75,45.25,56.59999847,84.19999695,80.0,24.75,20.20000076,19.35000038,50.59999847,81.15000153,89.90000153,85.30000305,108.0,93.5,20.25,25.14999962,29.60000038,73.15000153,19.75,86.59999847,109.1999969,74.69999695,94.40000153,54.79999924,75.34999847,65.0,99.0,93.5,83.69999695,19.85000038,59.54999924,115.0999985,114.3499985,45.0,89.84999847,49.84999847,113.3000031,88.09999847,24.89999962,105.0,24.25,59.75,107.0500031,64.94999695,55.0,50.54999924,55.15000153,51.20000076,25.39999962,54.45000076,76.0,44.34999847,61.20000076,86.80000305,89.34999847,19.70000076,20.25,76.05000305,100.8000031,74.55000305,64.90000153,90.40000153,60.29999924,81.84999847,24.79999924,75.55000305,101.1500015,78.75,19.25,89.05000305,115.0500031,69.34999847,110.0500031,19.89999962,91.5,60.0,44.79999924,48.59999847,60.04999924,102.6999969,82.90000153,35.90000153,82.65000153,19.85000038,19.20000076,94.90000153,88.15000153,94.80000305,54.65000153,85.75,67.44999695,20.5,20.25,72.09999847,19.45000076,44.95000076,97.0,62.79999924,44.59999847,89.15000153,54.09999847,105.25,97.09999847,20.20000076,98.80000305,50.29999924,20.54999924,75.90000153,59.95000076,19.14999962,98.65000153,112.5999985,20.60000038,35.75,99.75,96.09999847,85.09999847,25.35000038,89.65000153,86.75,86.19999695,64.80000305,108.0999985,54.75,90.40000153,44.0,95.59999847,84.80000305,44.29999924,19.89999962,95.05000305,90.05000305,109.9000015,54.59999847,20.04999924,19.75,20.04999924,55.90000153,19.70000076,19.79999924,95.40000153,93.94999695,24.45000076,74.94999695,87.34999847,70.65000153,73.25,98.69 ...

# %% [markdown]
# #### The scatter plot visualizes the relationship between churn and monthly charges. It allows us to observe whether there is any noticeable pattern or trend between higher charges and churn. It can help identify if customers with higher monthly charges are more likely to churn. This shows that charges between 70 to 110 have a higher chance to churn and also not churn which means no noticeable patterns

# %%
# Churn and contract information - Contract
# Analyzing the Churn Rate by Contract to observe any patterns associated with churn
contract_churn = training_data.groupby('Contract')['Churn'].value_counts(normalize=True).unstack().reset_index()
contract_churn.rename(columns={'No': 'No Churn', 'Yes': 'Churn'}, inplace=True)

fig = px.bar(contract_churn, x='Contract', y=['No Churn', 'Churn'], barmode='stack', title='Churn by Contract Type')
fig.show()
# Out:
# <div>                            <div id="b8e42359-a26b-4664-a757-d681021ebb8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8e42359-a26b-4664-a757-d681021ebb8c")) {                    Plotly.newPlot(                        "b8e42359-a26b-4664-a757-d681021ebb8c",                        [{"alignmentgroup":"True","hovertemplate":"variable=No Churn<br>Contract=%{x}<br>value=%{y}<extra></extra>","legendgroup":"No Churn","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No Churn","offsetgroup":"No Churn","orientation":"v","showlegend":true,"textposition":"auto","x":["Month-to-month","One year","Two year"],"xaxis":"x","y":[0.5685131195335277,0.8843601895734597,0.9758842443729904],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Churn<br>Contract=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Churn","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Churn","offsetgroup":"Churn","orientation":"v","showlegend":true,"textposition":"auto","x":["Month-to-month","One year","Two year"],"xaxis":"x","y":[0.4314868804664723,0.11563981042654028,0.024115755627009645],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoord ...

# %% [markdown]
# #### The stacked bar chart showcases the churn rates based on different contract types (Month-to-month, One year and Two years). It shows that a signicantly higher percentage of customers are likely to churn with a contract type of Month-to-month.

# %%
# Churn and customer tenure
# Analyzing the Churn Rate by customer tenure to observe any patterns associated with churn
plt.figure(figsize=(10, 6))
sns.histplot(training_data, x='tenure', hue='Churn', multiple='stack', bins=20, palette='Set1')
plt.title('Churn and Customer Tenure')
plt.xlabel('Tenure (Months)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### The histogram displays the distribution of customer tenure for both churned and non-churned customers over their tenure in months. This shows that customer loyalty goes a very long with the customers with the highest months(70) having the highest No Churn count compared to its churned count.
